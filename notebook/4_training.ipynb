# %%
import sys
sys.path.append('../src')

# パッケージのimport
import os.path as osp
import random
import time

import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)
# Out:
# 使用デバイス： cpu

# %% [markdown]
# # Create Dataloader

# %%
from dataloader import create_dataloader

path = '/Users/chi/Downloads/VOCdevkit/VOC2012'

# VOCで使われる20件のクラス名
voc_classes = ['aeroplane', 'bicycle', 'bird', 'boat',
            'bottle', 'bus', 'car', 'cat', 'chair',
            'cow', 'diningtable', 'dog', 'horse',
            'motorbike', 'person', 'pottedplant',
            'sheep', 'sofa', 'train', 'tvmonitor']

dataloader = create_dataloader(path, voc_classes)

# %% [markdown]
# # Create SSD model

# %%
from ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'input_feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'dbox_pixel_sizes': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'small_dbox_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'big_dbox_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'dbox_aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
    'input_channels': [512, 1024, 512, 256, 256, 256],
}

# SSDネットワークモデル
net = SSD(phase="train", config=ssd_cfg)

# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
vgg_weights = torch.load('../weights/vgg16_reducedfc.pth')
net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化


def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
net.extras.apply(weights_init)
net.location.apply(weights_init)
net.confidence.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# mean:  34928
# 使用デバイス： cpu
# ネットワーク設定完了：学習済みの重みをロードしました

# %% [markdown]
# # 損失関数と最適化手法を定義

# %%
from ssd_loss import SSD_Loss

# 損失関数の設定
criterion = SSD_Loss(jaccard_thresh=0.5, negpos_ratio=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD(net.parameters(), lr=1e-3,
                      momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# # 学習・検証を行う

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # イテレーションカウンタをセット
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードに
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)

                    # 損失の計算
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()  # 勾配の計算

                        # 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # パラメータ更新

                        if (iteration % 10 == 0):  # 10iterに1度、lossを表示
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('イテレーション {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/ssd300_' +
                       str(epoch+1) + '.pth')

# %%
# 学習・検証を実行する
num_epochs= 50  
train_model(net, dataloader, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用デバイス： cpu
# -------------
# Epoch 1/50
# -------------
# （train）
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 10 || Loss: 16.4619 || 10iter: 824.2362 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 20 || Loss: 12.3871 || 10iter: 811.1001 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 30 || Loss: 10.5161 || 10iter: 842.4698 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 40 || Loss: 9.2033 || 10iter: 780.5790 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 50 || Loss: 9.9181 || 10iter: 766.7532 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 60 || Loss: 9.0012 || 10iter: 775.4187 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 70 || Loss: 9.1927 || 10iter: 790.4445 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 80 || Loss: 9.4152 || 10iter: 795.5956 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 90 || Loss: 9.2730 || 10iter: 804.5642 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 100 || Loss: 9.1164 || 10iter: 45332.6804 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 110 || Loss: 9.5116 || 10iter: 780.3957 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 120 || Loss: 10.1117 || 10iter: 786.4848 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 130 || Loss: 9.1921 || 10iter: 799.2927 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 140 || Loss: 8.3694 || 10iter: 788.7326 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 150 || Loss: 9.7987 || 10iter: 781.5378 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 160 || Loss: 8.3696 || 10iter: 761.7975 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 170 || Loss: 8.8303 || 10iter: 838.2261 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([21, 512, 38, 38])
# -------------
# epoch 1 || Epoch_TRAIN_Loss:1850.9904 ||Epoch_VAL_Loss:0.0000
# timer:  58769.3806 sec.
# -------------
# Epoch 2/50
# -------------
# （train）
# torch.Size([32, 512, 38, 38])
# イテレーション 180 || Loss: 10.6703 || 10iter: 80.7506 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 190 || Loss: 8.7892 || 10iter: 781.5041 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 200 || Loss: 8.9206 || 10iter: 766.8227 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 210 || Loss: 8.7641 || 10iter: 763.4659 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 220 || Loss: 8.6420 || 10iter: 760.1149 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 230 || Loss: 9.6807 || 10iter: 862.9987 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 240 || Loss: 7.5918 || 10iter: 845.3740 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 250 || Loss: 10.5894 || 10iter: 833.7022 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 260 || Loss: 8.4997 || 10iter: 837.4624 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 270 || Loss: 9.3571 || 10iter: 832.4271 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 280 || Loss: 8.3561 || 10iter: 816.1187 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 290 || Loss: 7.9979 || 10iter: 824.3963 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 300 || Loss: 8.9713 || 10iter: 840.4282 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 310 || Loss: 8.6412 || 10iter: 790.2583 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 320 || Loss: 9.4599 || 10iter: 801.0799 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 330 || Loss: 9.3783 || 10iter: 798.7275 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 340 || Loss: 8.0014 || 10iter: 761.5391 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 350 || Loss: 8.7380 || 10iter: 760.7827 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([21, 512, 38, 38])
# -------------
# epoch 2 || Epoch_TRAIN_Loss:1561.4920 ||Epoch_VAL_Loss:0.0000
# timer:  14337.9839 sec.
# -------------
# Epoch 3/50
# -------------
# （train）
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 360 || Loss: 7.8070 || 10iter: 152.1115 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 370 || Loss: 9.9812 || 10iter: 781.1137 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 380 || Loss: 7.8717 || 10iter: 812.9941 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 390 || Loss: 9.2839 || 10iter: 821.2671 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 400 || Loss: 9.2751 || 10iter: 818.1077 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 410 || Loss: 11.6478 || 10iter: 814.6851 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 420 || Loss: 9.1155 || 10iter: 819.6339 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 430 || Loss: 10.8528 || 10iter: 804.9752 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 440 || Loss: 8.5676 || 10iter: 805.1924 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 450 || Loss: 9.1572 || 10iter: 799.3024 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 460 || Loss: 8.3039 || 10iter: 805.4830 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 470 || Loss: 8.9227 || 10iter: 794.8781 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 480 || Loss: 10.2197 || 10iter: 807.6288 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 490 || Loss: 8.3217 || 10iter: 808.9904 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 500 || Loss: 8.6079 || 10iter: 823.2545 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# イテレーション 510 || Loss: 8.9682 || 10iter: 806.4824 sec.
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
# torch.Size([32, 512, 38, 38])
